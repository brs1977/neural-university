# %% [markdown]
# #ДЗ pro
#
# Входные параметры:
#
# Готовая архитектура сети CustomNet для распознования CIFAR-10
#
# Задание:
#
# 1) Обучить сверточную сеть на датасете CIFAR-10 с разными функциями активациями, добавить слои свертки и пулинга, добавить нейронов и написать отчет об изменениях точностей.
#
# 2) Получить accuracy близкий к 0.8 и выше

# %%
import torch
import random
import numpy as np
import os
import torchvision.datasets

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# #Load data

# %%
CIFAR_train = torchvision.datasets.CIFAR10('./',download=True,train=True)
CIFAR_test = torchvision.datasets.CIFAR10('./',download=True,train=False)

X_train = torch.FloatTensor(CIFAR_train.data)
y_train = torch.LongTensor(CIFAR_train.targets)

X_test = torch.FloatTensor(CIFAR_test.data)
y_test = torch.LongTensor(CIFAR_test.targets)


X_train /= 255.
X_test /=255.

# меняем порядок размерности
X_train = X_train.permute(0,3,1,2)
X_test = X_test.permute(0,3,1,2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #Model1

# %%
import torch.nn as nn
class CustomNet(torch.nn.Module):
  def __init__(self):
    super(CustomNet,self).__init__()

    self.features = nn.Sequential(
            nn.Conv2d(3, channels, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(channels),
        
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(channels),            
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p = drop),
        
            nn.Conv2d(channels, channels*2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(channels*2),
        
            nn.Conv2d(channels*2, channels*2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(channels*2),            

            nn.Conv2d(channels*2, channels*2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(channels*2),            
        
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
          
    self.classifier = nn.Sequential(
            nn.Dropout(p = drop),
            nn.Linear(channels*2 * 8 * 8, fc_units),
            nn.BatchNorm1d(fc_units),
            nn.ReLU(inplace=True),
            nn.Dropout(p = drop),

            nn.Linear(fc_units, fc_units),
            nn.BatchNorm1d(fc_units),
            nn.ReLU(inplace=True),
            nn.Dropout(p = drop),
            nn.Linear(fc_units, 10),
        
#             nn.Linear(fc_units, 10), #77

#             nn.Linear(fc_units, fc_units//2),
#             nn.BatchNorm1d(fc_units//2),
#             nn.ReLU(inplace=True),
#             nn.Dropout(p = drop),
#             nn.Linear(fc_units//2, 10),
        
        
        )
    self.activation = nn.Softmax()
  def forward(self,x):    
    x = self.features(x)
    x = x.view(x.size(0), -1)
    x = self.classifier(x)
    #x = self.activation(x)

    return x

# %% [markdown]
# #Train model1

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

batch_size = 256
channels = 16
fc_units = 768
drop = .1

lenet5 = CustomNet()
lenet5 = lenet5.to(device)

loss = torch.nn.CrossEntropyLoss()
lr=1.0e-2
optimizer = torch.optim.Adam(lenet5.parameters(),lr=lr)



# tensors into gpu
X_test = X_test.to(device)
y_test = y_test.to(device)


num_epochs = 150    
for epoch in range(num_epochs):
  order = np.random.permutation(len(X_train))
  
  if epoch != 0 and epoch%3==0:    
    lr *= .8
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
        
    print ('lr set to {:.5f}:'.format(lr))
  
  train_preds = torch.tensor([],dtype=torch.uint8).to(device)
  train_accuracy = 0
  train_loss = 0
  for start_index in range(0,len(X_train), batch_size):        
    optimizer.zero_grad()
    batch_indexes = order[start_index:start_index+batch_size]
    
    X_batch = X_train[batch_indexes].to(device)
    y_batch = y_train[batch_indexes].to(device)
    
    preds = lenet5.forward(X_batch)        
    
    train_preds = torch.cat((train_preds,preds.argmax(dim=1) == y_batch), dim=0)
    
    loss_value = loss(preds, y_batch)
    
    train_loss += loss_value.item()
    
    loss_value.backward()
    
    optimizer.step()
  
  train_accuracy = train_preds.float().mean()
  
  test_preds = lenet5.forward(X_test)
  
  accuracy = (test_preds.argmax(dim=1) == y_test).float().mean().data.cpu()
  
  print('Epoch [{}/{}], Loss:{:.5f} , Accuracy:{:.5f}, Val Accuracy: {:.5f}'.format(epoch + 1, num_epochs, train_loss/(start_index+1),  train_accuracy, accuracy)  )
# Out:
# Epoch [1/150], Loss:0.00541 , Accuracy:0.49816, Val Accuracy: 0.61580
# Epoch [2/150], Loss:0.00371 , Accuracy:0.66460, Val Accuracy: 0.69650
# Epoch [3/150], Loss:0.00294 , Accuracy:0.73628, Val Accuracy: 0.73100
# lr set to 0.00800:
# Epoch [4/150], Loss:0.00234 , Accuracy:0.78932, Val Accuracy: 0.75810
# Epoch [5/150], Loss:0.00193 , Accuracy:0.82568, Val Accuracy: 0.76260
# Epoch [6/150], Loss:0.00161 , Accuracy:0.85256, Val Accuracy: 0.76540
# lr set to 0.00640:
# Epoch [7/150], Loss:0.00116 , Accuracy:0.89386, Val Accuracy: 0.77700
# Epoch [8/150], Loss:0.00095 , Accuracy:0.91442, Val Accuracy: 0.77510
# Epoch [9/150], Loss:0.00078 , Accuracy:0.92964, Val Accuracy: 0.76500
# lr set to 0.00512:
# Epoch [10/150], Loss:0.00052 , Accuracy:0.95400, Val Accuracy: 0.76970
# Epoch [11/150], Loss:0.00042 , Accuracy:0.96092, Val Accuracy: 0.78080
# Epoch [12/150], Loss:0.00040 , Accuracy:0.96346, Val Accuracy: 0.77620
# lr set to 0.00410:
# Epoch [13/150], Loss:0.00031 , Accuracy:0.97280, Val Accuracy: 0.77430
# Epoch [14/150], Loss:0.00023 , Accuracy:0.98014, Val Accuracy: 0.77970
# Epoch [15/150], Loss:0.00024 , Accuracy:0.97948, Val Accuracy: 0.78030
# lr set to 0.00328:
# Epoch [16/150], Loss:0.00018 , Accuracy:0.98454, Val Accuracy: 0.77950
# Epoch [17/150], Loss:0.00016 , Accuracy:0.98628, Val Accuracy: 0.78020
# Epoch [18/150], Loss:0.00015 , Accuracy:0.98666, Val Accuracy: 0.78150
# lr set to 0.00262:
# Epoch [19/150], Loss:0.00012 , Accuracy:0.98998, Val Accuracy: 0.78530
# Epoch [20/150], Loss:0.00010 , Accuracy:0.99120, Val Accuracy: 0.78910
# Epoch [21/150], Loss:0.00011 , Accuracy:0.99034, Val Accuracy: 0.78210
# lr set to 0.00210:
# Epoch [22/150], Loss:0.00009 , Accuracy:0.99252, Val Accuracy: 0.78730
# Epoch [23/150], Loss:0.00007 , Accuracy:0.99384, Val Accuracy: 0.78810
# Epoch [24/150], Loss:0.00008 , Accuracy:0.99316, Val Accuracy: 0.78460
# lr set to 0.00168:
# Epoch [25/150], Loss:0.00007 , Accuracy:0.99392, Val Accuracy: 0.78730
# Epoch [26/150], Loss:0.00007 , Accuracy:0.99438, Val Accuracy: 0.78730
# Epoch [27/150], Loss:0.00006 , Accuracy:0.99516, Val Accuracy: 0.78300
# lr set to 0.00134:
# Epoch [28/150], Loss:0.00005 , Accuracy:0.99554, Val Accuracy: 0.78770
# Epoch [29/150], Loss:0.00005 , Accuracy:0.99586, Val Accuracy: 0.79040
# Epoch [30/150], Loss:0.00004 , Accuracy:0.99634, Val Accuracy: 0.78950
# lr set to 0.00107:
# Epoch [31/150], Loss:0.00005 , Accuracy:0.99604, Val Accuracy: 0.78970
# Epoch [32/150], Loss:0.00004 , Accuracy:0.99682, Val Accuracy: 0.79370
# Epoch [33/150], Loss:0.00004 , Accuracy:0.99708, Val Accuracy: 0.79060
# lr set to 0.00086:
# Epoch [34/150], Loss:0.00003 , Accuracy:0.99748, Val Accuracy: 0.79220
# Epoch [35/150], Loss:0.00003 , Accuracy:0.99752, Val Accuracy: 0.79110
# Epoch [36/150], Loss:0.00003 , Accuracy:0.99730, Val Accuracy: 0.79280
# lr set to 0.00069:
# Epoch [37/150], Loss:0.00003 , Accuracy:0.99782, Val Accuracy: 0.79430
# Epoch [38/150], Loss:0.00003 , Accuracy:0.99774, Val Accuracy: 0.79070
# Epoch [39/150], Loss:0.00003 , Accuracy:0.99780, Val Accuracy: 0.79010
# lr set to 0.00055:
# Epoch [40/150], Loss:0.00002 , Accuracy:0.99822, Val Accuracy: 0.79390
# Epoch [41/150], Loss:0.00002 , Accuracy:0.99862, Val Accuracy: 0.79450
# Epoch [42/150], Loss:0.00002 , Accuracy:0.99802, Val Accuracy: 0.79530
# lr set to 0.00044:
# Epoch [43/150], Loss:0.00002 , Accuracy:0.99814, Val Accuracy: 0.79250
# Epoch [44/150], Loss:0.00002 , Accuracy:0.99826, Val Accuracy: 0.79330
# Epoch [45/150], Loss:0.00002 , Accuracy:0.99864, Val Accuracy: 0.79420
# lr set to 0.00035:
# Epoch [46/150], Loss:0.00002 , Accuracy:0.99878, Val Accuracy: 0.79340
# Epoch [47/150], Loss:0.00002 , Accuracy:0.99864, Val Accuracy: 0.79290
# Epoch [48/150], Loss:0.00002 , Accuracy:0.99846, Val Accuracy: 0.79470
# lr set to 0.00028:
# Epoch [49/150], Loss:0.00002 , Accuracy:0.99846, Val Accuracy: 0.79910
# Epoch [50/150], Loss:0.00002 , Accuracy:0.99854, Val Accuracy: 0.79500
# Epoch [51/150], Loss:0.00002 , Accuracy:0.99884, Val Accuracy: 0.79340
# lr set to 0.00023:
# Epoch [52/150], Loss:0.00002 , Accuracy:0.99872, Val Accuracy: 0.79340
# Epoch [53/150], Loss:0.00002 , Accuracy:0.99886, Val Accuracy: 0.79320
# Epoch [54/150], Loss:0.00002 , Accuracy:0.99874, Val Accuracy: 0.79330
# lr set to 0.00018:
# Epoch [55/150], Loss:0.00001 , Accuracy:0.99878, Val Accuracy: 0.79380
# Epoch [56/150], Loss:0.00001 , Accuracy:0.99888, Val Accuracy: 0.79300
# Epoch [57/150], Loss:0.00001 , Accuracy:0.99890, Val Accuracy: 0.79680
# lr set to 0.00014:
# Epoch [58/150], Loss:0.00001 , Accuracy:0.99908, Val Accuracy: 0.79330
# Epoch [59/150], Loss:0.00001 , Accuracy:0.99890, Val Accuracy: 0.79060
# Epoch [60/150], Loss:0.00001 , Accuracy:0.99904, Val Accuracy: 0.79690
# lr set to 0.00012:
# Epoch [61/150], Loss:0.00001 , Accuracy:0.99918, Val Accuracy: 0.79340
# Epoch [62/150], Loss:0.00001 , Accuracy:0.99894, Val Accuracy: 0.79400
# Epoch [63/150], Loss:0.00001 , Accuracy:0.99918, Val Accuracy: 0.79920
# lr set to 0.00009:
# Epoch [64/150], Loss:0.00001 , Accuracy:0.99900, Val Accuracy: 0.79270
# Epoch [65/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79190
# Epoch [66/150], Loss:0.00001 , Accuracy:0.99906, Val Accuracy: 0.79600
# lr set to 0.00007:
# Epoch [67/150], Loss:0.00001 , Accuracy:0.99922, Val Accuracy: 0.79470
# Epoch [68/150], Loss:0.00002 , Accuracy:0.99884, Val Accuracy: 0.79770
# Epoch [69/150], Loss:0.00001 , Accuracy:0.99914, Val Accuracy: 0.79270
# lr set to 0.00006:
# Epoch [70/150], Loss:0.00001 , Accuracy:0.99910, Val Accuracy: 0.79450
# Epoch [71/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.79340
# Epoch [72/150], Loss:0.00001 , Accuracy:0.99930, Val Accuracy: 0.79260
# lr set to 0.00005:
# Epoch [73/150], Loss:0.00001 , Accuracy:0.99892, Val Accuracy: 0.79430
# Epoch [74/150], Loss:0.00001 , Accuracy:0.99902, Val Accuracy: 0.79530
# Epoch [75/150], Loss:0.00001 , Accuracy:0.99942, Val Accuracy: 0.79510
# lr set to 0.00004:
# Epoch [76/150], Loss:0.00001 , Accuracy:0.99900, Val Accuracy: 0.80010
# Epoch [77/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79550
# Epoch [78/150], Loss:0.00001 , Accuracy:0.99926, Val Accuracy: 0.79310
# lr set to 0.00003:
# Epoch [79/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79710
# Epoch [80/150], Loss:0.00001 , Accuracy:0.99926, Val Accuracy: 0.79580
# Epoch [81/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79590
# lr set to 0.00002:
# Epoch [82/150], Loss:0.00001 , Accuracy:0.99908, Val Accuracy: 0.79530
# Epoch [83/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79830
# Epoch [84/150], Loss:0.00001 , Accuracy:0.99910, Val Accuracy: 0.79620
# lr set to 0.00002:
# Epoch [85/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79690
# Epoch [86/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79730
# Epoch [87/150], Loss:0.00001 , Accuracy:0.99902, Val Accuracy: 0.79550
# lr set to 0.00002:
# Epoch [88/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79550
# Epoch [89/150], Loss:0.00001 , Accuracy:0.99914, Val Accuracy: 0.79770
# Epoch [90/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.79530
# lr set to 0.00001:
# Epoch [91/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.79570
# Epoch [92/150], Loss:0.00001 , Accuracy:0.99904, Val Accuracy: 0.79810
# Epoch [93/150], Loss:0.00001 , Accuracy:0.99912, Val Accuracy: 0.79810
# lr set to 0.00001:
# Epoch [94/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79610
# Epoch [95/150], Loss:0.00001 , Accuracy:0.99902, Val Accuracy: 0.79990
# Epoch [96/150], Loss:0.00001 , Accuracy:0.99906, Val Accuracy: 0.79720
# lr set to 0.00001:
# Epoch [97/150], Loss:0.00001 , Accuracy:0.99882, Val Accuracy: 0.79590
# Epoch [98/150], Loss:0.00001 , Accuracy:0.99932, Val Accuracy: 0.79680
# Epoch [99/150], Loss:0.00001 , Accuracy:0.99932, Val Accuracy: 0.79910
# lr set to 0.00001:
# Epoch [100/150], Loss:0.00001 , Accuracy:0.99904, Val Accuracy: 0.79490
# Epoch [101/150], Loss:0.00001 , Accuracy:0.99888, Val Accuracy: 0.79600
# Epoch [102/150], Loss:0.00001 , Accuracy:0.99930, Val Accuracy: 0.79820
# lr set to 0.00001:
# Epoch [103/150], Loss:0.00001 , Accuracy:0.99906, Val Accuracy: 0.79770
# Epoch [104/150], Loss:0.00001 , Accuracy:0.99934, Val Accuracy: 0.79730
# Epoch [105/150], Loss:0.00001 , Accuracy:0.99940, Val Accuracy: 0.79750
# lr set to 0.00000:
# Epoch [106/150], Loss:0.00001 , Accuracy:0.99926, Val Accuracy: 0.79910
# Epoch [107/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79460
# Epoch [108/150], Loss:0.00001 , Accuracy:0.99938, Val Accuracy: 0.79160
# lr set to 0.00000:
# Epoch [109/150], Loss:0.00001 , Accuracy:0.99926, Val Accuracy: 0.79450
# Epoch [110/150], Loss:0.00001 , Accuracy:0.99928, Val Accuracy: 0.79420
# Epoch [111/150], Loss:0.00001 , Accuracy:0.99912, Val Accuracy: 0.79190
# lr set to 0.00000:
# Epoch [112/150], Loss:0.00001 , Accuracy:0.99916, Val Accuracy: 0.79600
# Epoch [113/150], Loss:0.00001 , Accuracy:0.99914, Val Accuracy: 0.79860
# Epoch [114/150], Loss:0.00001 , Accuracy:0.99938, Val Accuracy: 0.79730
# lr set to 0.00000:
# Epoch [115/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.80030
# Epoch [116/150], Loss:0.00001 , Accuracy:0.99918, Val Accuracy: 0.79660
# Epoch [117/150], Loss:0.00001 , Accuracy:0.99914, Val Accuracy: 0.79550
# lr set to 0.00000:
# Epoch [118/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.79640
# Epoch [119/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79700
# Epoch [120/150], Loss:0.00001 , Accuracy:0.99930, Val Accuracy: 0.79360
# lr set to 0.00000:
# Epoch [121/150], Loss:0.00001 , Accuracy:0.99916, Val Accuracy: 0.79550
# Epoch [122/150], Loss:0.00001 , Accuracy:0.99926, Val Accuracy: 0.79660
# Epoch [123/150], Loss:0.00001 , Accuracy:0.99906, Val Accuracy: 0.79710
# lr set to 0.00000:
# Epoch [124/150], Loss:0.00001 , Accuracy:0.99912, Val Accuracy: 0.79950
# Epoch [125/150], Loss:0.00001 , Accuracy:0.99894, Val Accuracy: 0.79550
# Epoch [126/150], Loss:0.00001 , Accuracy:0.99928, Val Accuracy: 0.79330
# lr set to 0.00000:
# Epoch [127/150], Loss:0.00001 , Accuracy:0.99912, Val Accuracy: 0.79460
# Epoch [128/150], Loss:0.00001 , Accuracy:0.99918, Val Accuracy: 0.79530
# Epoch [129/150], Loss:0.00001 , Accuracy:0.99922, Val Accuracy: 0.79760
# lr set to 0.00000:
# Epoch [130/150], Loss:0.00001 , Accuracy:0.99928, Val Accuracy: 0.79950
# Epoch [131/150], Loss:0.00001 , Accuracy:0.99910, Val Accuracy: 0.79800
# Epoch [132/150], Loss:0.00001 , Accuracy:0.99932, Val Accuracy: 0.79430
# lr set to 0.00000:
# Epoch [133/150], Loss:0.00001 , Accuracy:0.99908, Val Accuracy: 0.79820
# Epoch [134/150], Loss:0.00001 , Accuracy:0.99916, Val Accuracy: 0.79390
# Epoch [135/150], Loss:0.00001 , Accuracy:0.99938, Val Accuracy: 0.79480
# lr set to 0.00000:
# Epoch [136/150], Loss:0.00001 , Accuracy:0.99908, Val Accuracy: 0.79560
# Epoch [137/150], Loss:0.00001 , Accuracy:0.99906, Val Accuracy: 0.79460
# Epoch [138/150], Loss:0.00001 , Accuracy:0.99924, Val Accuracy: 0.79710
# lr set to 0.00000:
# Epoch [139/150], Loss:0.00001 , Accuracy:0.99930, Val Accuracy: 0.79910
# Epoch [140/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79250
# Epoch [141/150], Loss:0.00001 , Accuracy:0.99940, Val Accuracy: 0.79660
# lr set to 0.00000:
# Epoch [142/150], Loss:0.00001 , Accuracy:0.99888, Val Accuracy: 0.79990
# Epoch [143/150], Loss:0.00001 , Accuracy:0.99920, Val Accuracy: 0.79780
# Epoch [144/150], Loss:0.00001 , Accuracy:0.99928, Val Accuracy: 0.79790
# lr set to 0.00000:
# Epoch [145/150], Loss:0.00001 , Accuracy:0.99932, Val Accuracy: 0.79430
# Epoch [146/150], Loss:0.00001 , Accuracy:0.99894, Val Accuracy: 0.79420
# Epoch [147/150], Loss:0.00001 , Accuracy:0.99904, Val Accuracy: 0.79500
# lr set to 0.00000:
# Epoch [148/150], Loss:0.00001 , Accuracy:0.99938, Val Accuracy: 0.79460
# Epoch [149/150], Loss:0.00001 , Accuracy:0.99936, Val Accuracy: 0.79140
# Epoch [150/150], Loss:0.00001 , Accuracy:0.99936, Val Accuracy: 0.79970

# %% [markdown]
# #Вывод
#
# [Colab](https://colab.research.google.com/drive/1e14Vh74QYZpwYFqF3IVJEBlg2B8xklyp)
#
# Использовал модель типа ConvNet с 5 слоями свертки (меньше сеть сделать не получилось, с увеличением числа каналов не хватает памяти GPU), и двух полносвязных слоев,  сеть достигает 80% к 76 эпохе.
